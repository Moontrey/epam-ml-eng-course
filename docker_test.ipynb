# %%
import pandas as pd
import numpy as np
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
np.__version__
# Out:
# '1.15.0'

# %%
# !pip install pyarrow

# !pip install fastparquet
# Out:
# Collecting pyarrow
#   Using cached https://files.pythonhosted.org/packages/3a/9b/887d1d03d3d43706dee3a71cdad9f9bbb8fe74fc93d8db5d663f5bf34e48/pyarrow-1.0.1-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.14 in /opt/conda/lib/python3.6/site-packages (from pyarrow) (1.15.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-1.0.1
# Collecting fastparquet
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.6/site-packages (from fastparquet) (0.23.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from fastparquet) (1.12.0)
# Requirement already satisfied: numpy>=1.11 in /opt/conda/lib/python3.6/site-packages (from fastparquet) (1.15.0)
# Collecting thrift>=0.11.0 (from fastparquet)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from fastparquet) (18.0)
# Requirement already satisfied: numba>=0.28 in /opt/conda/lib/python3.6/site-packages (from fastparquet) (0.38.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.6/site-packages (from pandas>=0.19->fastparquet) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas>=0.19->fastparquet) (2018.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->fastparquet) (2.3.0)
# Requirement already satisfied: llvmlite>=0.23.0dev0 in /opt/conda/lib/python3.6/site-packages (from numba>=0.28->fastparquet) (0.23.0)
# Installing collected packages: thrift, fastparquet
# Successfully installed fastparquet-0.4.1 thrift-0.13.0

# %%
article_contents = pd.read_parquet('uci_news.snappy.parquet')

# %%
Y_train = article_contents.category.iloc[0:train_row]

# %%
from sklearn.feature_extraction.text import CountVectorizer
train_row = 5000
label_prefix = '__label__'
count_vectorizer = CountVectorizer(min_df=0, max_df=0.99, max_features=10000)
X_train = count_vectorizer.fit_transform(article_contents.main_content.iloc[0:train_row])
X_train = count_vectorizer.inverse_transform(X_train)
with open("uci_train_starspace_formatted.txt", 'w+') as file:
    for i in range(train_row):
        file.write(' '.join(X_train[i]) + ' ' + label_prefix + Y_train.iloc[i])
        file.write('\n')
file.close()

# %%
X_train
# Out:
# [array(['story', 'contributed', 'ryan', 'jennifer', 'delaware', 'jersey',
#         'southern', 'pennsylvania', 'eastern', 'includes', 'district',
#         '2006', 'august', 'became', 'economist', 'rochester', 'university',
#         'former', 'work', 'find', 'couldn', 'force', 'entered', 'people',
#         'before', 'rose', 'figures', 'department', 'below', 'falls',
#         'well', 'zero', 'interest', 'main', 'keep', 'show', 'continues',
#         'long', 'easing', 'quantitative', 'called', 'so', 'gradual',
#         'press', 'pledged', 'weak', 'months', 'previous', 'other',
#         'follow', 'they', 'though', 'were', 'numbers', 'jobs', 'about',
#         'asked', 'when', 'be', 'shouldn', '65', 'reduced', 'january',
#         'meetings', 'two', 'past', 'each', 'bond', 'monthly', 'reason',
#         'one', 'labour', 'improvement', 'saw', 'whip', 'no', 'estimated',
#         'initially', 'bigger', 'was', 'prior', 'increase', '129',
#         'revised', 'followed', 'employment', 'gain', '000', '175', 'back',
#         'bounce', 'starting', 'indicating', 'showed', 'week', 'february',
#         'projected', 'than', 'workers', 'more', 'added', 'employers', 'us',
#         'time', 'considerable', 'warrant', 'inflation', 'low',
#         'unemployment', 'as', 'even', 'outlook', 'favorable', 'reasonably',
#         'sees', 'he', 'dudley', 'william', 'york', 'new', 'month', 'last',
#         'ben', 'succeeded', 'she', 'since', 'yellen', 'janet', 'chair',
#         'by', 'led', 'gathering', 'first', 'march', '19', '18', 'meets',
#         'fomc', 'committee', 'market', 'open', 'setting', 'growth',
#         'obstacles', 'fundamental', 'weather', 'winter', 'severe',
#         'because', 'weakness', 'signs', 'shown', 'has', 'economy',
#         'whether', 'determine', 'trying', 'direction', 'either', 'high',
#         'pretty', 'is', 'for', 'rate', 'hurdle', 'billion', '10',
#         'continue', 'ok', 'doing', 're', 'what', 'markets', 'clarity',
#         'least', 'or', 'certainty', 'some', 'give', 'important',
#         'reductions', 'measured', 'embarked', 've', 'that', 'fact',
#         'given', 'programme', 'stimulus', 'its', 'tapering', 'fed',
#         'referring', 'with', 'interview', 'television', 'bloomberg', 'in',
#         'faster', 'at', 'started', 'we', 'had', 'perspective', 'my',
#         'from', 'nice', 'been', 'have', 'would', 'it', 'purchases',
#         'asset', 'central', 'pace', 'change', 'enough', 'isn', 'data',
#         'economic', 'encouraging', 'recent', 'said', 'year', 'this',
#         'policy', 'on', 'votes', 'who', 'plosser', 'charles', 'president',
#         'philadelphia', 'bank', 'reserve', 'federal', 'atlanta', 'london',
#         'paris'], dtype='<U18'),
#  array(['reserved', 'rights', 'reuters', 'thomson', '2018', 'gave', 'same',
#         'largely', 'reference', 'aside', 'far', 'largest', 'world',
#         'sales', 'retail', 'manufacturing', 'despite', 'steps',
#         'policymakers', 'but', 'hiring', 'spur', 'meant', 'which',
#         'program', 'buying', 'aggressive', 'critic', 'search', 'into',
#         'flooded', 'americans', 'five', 'percent', 'meanwhile',
#         'positions', 'creating', 'after', 'friday', 'report', 'government',
#         'remarks', 'prepared', 'according', 'unusually', 'effect', 'part',
#         'reflected', 'most', 'these', 'three', 'all', 'december', 'gains',
#         'pointed', 'france', 'speech', 'temporary', 'only', 'labor', 'bit',
#         'suggest', 'banker', 'latest', 'monday', 'official', 'top',
#         'affected', 'likely', 'work', 'rose', 'long', 'so', 'weak',
#         'numbers', 'jobs', 'january', 'bond', 'was', '129', '000', '175',
#         'showed', 'february', 'added', 'employers', 'time', 'low',
#         'unemployment', 'as', 'he', 'new', 'month', 'last', 'march',
#         'market', 'growth', 'weather', 'winter', 'severe', 'weakness',
#         'economy', 'is', 'for', 'rate', 'some', 'measured', 'fed', 'in',
#         'at', 'from', 'have', 'central', 'economic', 'said', 'year',
#         'this', 'on', 'plosser', 'charles', 'president', 'philadelphia',
#         'bank', 'reserve', 'federal', 'london'], dtype='<U18'),
#  array(['losers', 'winners', 'biggest', 'bull', 'jeff', 'levels', 'margin',
#         'stocks', 'sign', 'warning', 'strategy', 'exit', 'shifting', 'wsj',
#         'marketwatch', 'reads', 'session', 'answer', 'question', 'know',
#         'never', 'you', 'smoothly', 'very', 'go', 'wood', 'knock',
#         'disrupting', 'without', 'sheet', 'balance', 'size', 'reduce',
#         'ultimately', 'might', 'how', 'concerns', 'raised', 'also',
#         'opposite', 'perhaps', 'should', 'suggests', 'history',
#         'environment', 'still', 'ourselves', 'could', 'improve', 'fast',
#         'not', 'noted', 'later', 'end', 'will', 'current', 'purchase',
#         'cut', 'announced', 'improves', 'output', 'real', '2013', 'half',
#         'second', 'expansion', 'accelerated', 'product', 'domestic',
#         'gross', 'based', 'forecasts', 'out', 'play', 'if', 'curve',
#         'behind', 'leave', 'right', 'moving', 'reducing', 'panel', 'told',
#         'an', 'manner', 'degree', 'increasing', 'away', 'must', 'future',
#         'near', 'forecast', 'improving', 'ongoing', 'currently', 'account',
#         'take', 'accelerate', 'may', 'steps', 'but', 'which', 'program',
#         'into', 'after', 'according', 'all', 'speech', 'latest', 'monday',
#         'find', 'well', 'continues', 'numbers', 'about', 'be', '65',
#         'january', 'monthly', 'increase', 'back', 'showed', 'more', 'us',
#         'inflation', 'as', 'outlook', 'he', 'first', 'fomc', 'market',
#         'growth', 'economy', 'trying', 'direction', 'high', 'is', 'for',
#         'billion', 'or', 'measured', 'that', 'its', 'tapering', 'fed',
#         'with', 'in', 'at', 'we', 'from', 'have', 'would', 'it',
#         'purchases', 'asset', 'pace', 'enough', 'economic', 'said', 'year',
#         'this', 'policy', 'on', 'plosser', 'charles', 'president',
#         'philadelphia', 'bank', 'reserve', 'federal', 'paris'],
#        dtype='<U18'),
#  array(['seven', 'operation', 'tender', 'weekly', '90', 'borrow', 'survey',
#         'regular', 'remaining', 'come', 'nine', 'expect', '24', '14',
#         'provide', 'bloc', 'extra', 'accelerating', 'amount', 'times',
#         'six', 'day', 'their', 'cover', 'need', 'beyond', 'cash', 'push',
#         'helping', 'those', 'little', 'constraints', 'funding', 'ride',
#         'lenders', '2012', '2011', 'operations', 'refinancing', 'term',
#         'trillion', 'over', 'return', 'set', 'are', '11', 'less', 'next',
#         'loans', 'emergency', 'euros', 'banks', 'predicted', 'poll',
#         'limited', 'relatively', 'benefits', 'draghi', 'mario', 'chief',
#         'recovery', 'fragile', 'bolster', 'measures', 'unveiled', 'hold',
#         'left', 'event', 'rates', 'lending', 'down', 'bring', 'help',
#         'system', 'financial', 'liquidity', 'excess', 'boost', 'meeting',
#         'thursday', 'halt', 'announce', 'investors', 'economists', 'while',
#         'expected', '23', 'holds', 'value', 'equal', 'deposits',
#         'offering', 'fuelling', 'avoid', 'stable', 'supply', 'order',
#         'yields', 'counter', 'attempt', 'securities', 'through',
#         'countries', 'troubled', 'bonds', 'bought', 'september', 'ecb',
#         'headquarters', 'seen', 'landmark', 'polled', 'traders', 'money',
#         'majority', 'crisis', 'debt', 'zone', 'euro', 'height', 'made',
#         'stop', 'european', 'bangalore', 'levels', 'sign', 'not', 'will',
#         '2013', 'half', 'out', 'if', 'an', 'take', 'reuters', 'steps',
#         'into', 'five', 'government', 'three', 'december', 'only',
#         'before', 'interest', 'keep', 'long', 'months', 'other', 'they',
#         'asked', 'when', 'be', 'january', 'two', 'bond', 'monthly', 'one',
#         'no', 'was', 'showed', 'week', 'february', 'than', 'more',
#         'inflation', 'as', 'month', 'last', 'since', 'by', 'market', 'is',
#         'for', 'billion', 'continue', 'doing', 'what', 'some', 'that',
#         'programme', 'its', 'in', 'at', 'had', 'have', 'would', 'it',
#         'purchases', 'central', 'said', 'year', 'this', 'policy', 'on',
#         'who', 'bank'], dtype='<U18'),
#  array(['purpose', 'fit', 'something', 'turned', 'bullets', 'bite', 'won',
#         'alone', 'face', 'point', 'suit', 'currencies', 'regime', 'limits',
#         'such', 'impose', 'prefer', 'own', 'certain', 'dealt', 'address',
#         'nothing', 'does', 'se', 'per', 'yet', 'infect', 'now',
#         'phenomenon', 'big', 'themselves', 'lobbying', 'supervisors',
#         'luck', 'responsible', 'result', 'required', 'contagion', 'off',
#         'packed', 'exactly', 'spell', 'plans', 'resolution', 'draw',
#         'again', 'whole', 'cause', 'bankruptcy', 'fail', 'deemed', 'where',
#         'situations', 'avoiding', 'matter', 'then', 'robust', 'produce',
#         'influence', 'use', 'proposal', 'global', 'nations', '20', 'group',
#         'done', 'can', 'minimum', 'solution', 'bailed', 'easily',
#         'stability', 'supervisor', 'units', 'parts', 'responsibility',
#         'bodies', 'multiple', 'strongly', 'growing', 'fears', 'jack',
#         'like', 'things', 'authorities', 'national', 'tell', 'allow',
#         'powers', 'known', 'role', 'going', 'needs', 'initiatives',
#         'speed', 'forward', 'eu', 'necessary', 'close', 'easy',
#         'restructuring', 'equity', 'run', 'capital', 'forcing', 'credit',
#         'preventing', 'involves', 'years', 'pursuing', 'globe', 'around',
#         'broad', 'indeed', 'bill', 'foot', 'require', 'do', 'place', 'get',
#         'don', 'safe', 'make', 'business', 'taxpayers', 'problem', 'look',
#         'alternatives', 'better', 'there', 'think', 'mistake', 'flaw',
#         'serious', 'remains', 'many', 'too', 'states', 'latter', 'dragged',
#         'elements', 'connected', 'loop', 'doom', 'actually', 'understand',
#         'see', 'disaster', 'doesn', 'up', 'beef', 'parliament', 'bust',
#         'plan', 'diluted', 'bailing', 'hook', 'want', 'didn', 'common',
#         'supervision', 'attention', 'much', 'previously', 'hadn', 'onto',
#         'germany', 'different', 'completely', 'factory', 'emerged',
#         'systems', 'support', 'enthusiasts', 'why', 'rescue',
#         'governments', 'ability', 'faith', 'lost', 'them', 'able', 'net',
#         'safety', 'strong', 'trouble', 'got', 'scheme', 'insurance',
#         'deposit', 'wide', 'funded', 'idea', 'early', 'days', 'dark',
#         'during', 'prevent', 'way', 'advocates', 'original', 'wanted',
#         'designers', 'agreed', 'problems', 'solve', 'needed', 'strictly',
#         'wasn', 'banking', 'baked', 'union', 'provide', 'amount', 'their',
#         'need', 'push', 'ride', 'lenders', '2012', 'over', 'are', 'less',
#         'banks', 'hold', 'down', 'system', 'financial', 'investors',
#         'countries', 'bonds', 'bought', 'ecb', 'crisis', 'debt', 'zone',
#         'euro', 'made', 'stop', 'european', 'without', 'how', 'also',
#         'should', 'still', 'could', 'not', 'later', 'end', 'will', 'cut',
#         'half', 'second', 'out', 'if', 'told', 'may', 'despite', 'but',
#         'into', 'five', 'meanwhile', 'part', 'these', 'all', 'only',
#         'work', 'force', 'well', 'so', 'weak', 'other', 'follow', 'they',
#         'though', 'asked', 'be', 'two', 'past', 'one', 'saw', 'was',
#         'than', 'more', 'as', 'even', 'new', 'by', 'first', 'because',
#         'has', 'trying', 'is', 'for', 'doing', 'what', 'clarity', 'or',
#         'some', 'important', 'that', 'programme', 'its', 'with', 'in',
#         'at', 'had', 'from', 'been', 'have', 'would', 'it', 'central',
#         'enough', 'isn', 'said', 'year', 'this', 'policy', 'on', 'who',
#         'bank'], dtype='<U18'),
#  array(['guarantees', 'state', 'receive', 'bailout', 'short', 'decide',
#         'finally', 'just', 'available', 'fully', 'full', '76', '55',
#         'slated', 'filled', 'dip', 'soon', 'shutting', 'costs', 'used',
#         'build', 'say', 'declare', 'institution', 'ahead', 'arguing',
#         'involvement', 'hand', 'quickly', 'completed', 'procedure',
#         'start', 'commission', 'involve', 'scenario', 'under', 'signed',
#         'board', 'taken', 'decision', 'any', 'checks', 'authority',
#         'reluctant', 'closing', 'process', 'complex', 'dispute', 'heart',
#         'become', 'amongst', 'disagree', 'matters', 'further', 'until',
#         'possible', 'caution', 'officials', 'war', 'backed', 'others',
#         'imposed', 'wants', 'wider', 'giving', 'november', 'takes',
#         'issues', 'sensitive', 'touches', 'launch', 'loan', 'every',
#         'roughly', 'italy', 'exposure', 'relative', 'highest', 'assets',
#         'equivalent', '75', 'name', 'default', 'greece', 'free', 'risk',
#         'treated', 'buy', 'circle', 'break', 'supposed', 'recession',
#         'risks', 'raise', 'efforts', 'finance', 'french', 'german',
#         'italian', 'spanish', 'project', 'political', 'scale', 'large',
#         'economies', 'foster', 'currency', 'across', 'another',
#         'confidence', 'restore', 'intended', 'books', 'clean', 'parties',
#         'count', 'higher', 'probably', 'law', 'failure', 'april', 'mid',
#         'sitting', 'closures', 'fund', 'shut', 'agency', 'agreement',
#         'optimistic', 'de', 'minister', 'spain', 'counterparts', 'talks',
#         'reporters', 'wednesday', 'tomorrow', 'today', 'outcome', 'pay',
#         'pot', 'rules', 'mean', 'step', 'final', 'span', 'negotiations',
#         'approval', 'win', 'runs', 'reform', 'clearing', 'failing', 'wind',
#         'reach', 'try', 'lawmakers', 'donnell', 'john', 'jan', 'losses',
#         'investor', 'imposing', 'including', 'debate', 'ministers',
#         'delay', 'embarrassing', 'deal', 'point', 'such', 'now',
#         'themselves', 'resolution', 'then', 'use', 'group', 'can',
#         'supervisor', 'authorities', 'national', 'allow', 'role', 'eu',
#         'necessary', 'close', 'capital', 'years', 'around', 'do', 'place',
#         'make', 'there', 'states', 'see', 'up', 'parliament', 'want',
#         'much', 'germany', 'governments', 'able', 'trouble', 'scheme',
#         'early', 'days', 'prevent', 'way', 'agreed', 'banking', 'union',
#         'seven', 'borrow', 'bloc', 'day', 'their', 'cover', 'need', 'cash',
#         'helping', 'those', 'trillion', 'over', 'return', 'set', 'are',
#         'euros', 'banks', 'poll', 'hold', 'lending', 'down', 'system',
#         'boost', 'meeting', 'investors', 'while', 'expected', 'countries',
#         'troubled', 'ecb', 'landmark', 'money', 'debt', 'zone', 'euro',
#         'european', 'biggest', 'you', 'go', 'size', 'how', 'also',
#         'should', 'still', 'could', 'not', 'end', 'will', 'cut', 'real',
#         'out', 'if', 'leave', 'told', 'an', 'must', 'take', 'may',
#         'reuters', 'same', 'despite', 'policymakers', 'but', 'which',
#         'into', 'percent', 'after', 'government', 'according', 'three',
#         'all', 'december', 'only', 'monday', '2006', 'entered', 'before',
#         'well', 'so', 'months', 'other', 'they', 'about', 'be', 'one',
#         'no', 'was', 'week', 'more', 'time', 'as', 'he', 'new', 'month',
#         'last', 'since', 'by', 'first', 'march', '18', 'growth', 'because',
#         'has', 'economy', 'whether', 'is', 'for', 'rate', 'billion', '10',
#         'least', 'or', 'give', 'that', 'its', 'referring', 'with', 'in',
#         'at', 'from', 'been', 'have', 'would', 'it', 'central', 'change',
#         'said', 'year', 'this', 'on', 'who', 'bank'], dtype='<U18'),
#  array(['jeremy', 'editing', 'pressure', 'downward', 'put', 'exchange',
#         'happy', 'noyer', 'christian', 'hit', 'appreciation',
#         'significantly', 'member', 'agree', 'highly', 'qe', 'relying',
#         'england', 'japan', 'major', 'lend', 'tool', 'powerful', 'leaves',
#         'paying', 'increasingly', 'ease', 'late', 'handed', 'similar',
#         'party', 'third', 'changes', 'regulatory', 'legal', 'agenda',
#         'companies', 'sized', 'small', 'especially', 'revive', '58',
#         'worth', 'portfolio', 'few', 'instruments', 'room', 'council',
#         'governing', 'limitations', 'best', 'hoping', 'seems',
#         'throughout', 'remain', 'expects', 'example', 'deutsche', 'shine',
#         'taking', 'none', 'measure', 'greek', 'spent', 'withdrawal', '25',
#         'record', 'deflation', 'fight', 'print', 'forced', 'minority',
#         'weighing', 'stock', 'improvements', 'stay', 'stance', 'monetary',
#         'our', 'medium', 'extending', 'subdued', 'reasons', 'capacity',
#         'conference', 'news', 'post', 'statement', 'opening', 'send',
#         'seemed', 'view', 'slightly', 'took', 'dollar', 'against',
#         'target', 'rises', 'price', '2016', 'published', 'action', 'lack',
#         'disappointed', 'however', 'message', 'dovish', 'sending', 'pick',
#         'intends', 'shows', 'slack', 'emphasis', 'guarantees', 'short',
#         'just', 'ahead', 'under', 'further', 'launch', 'buy', 'risks',
#         'political', 'another', 'intended', 'probably', 'optimistic',
#         'step', 'such', 'now', 'big', 'off', 'then', 'stability',
#         'growing', 'like', 'close', 'require', 'do', 'place', 'remains',
#         'see', 'up', 'governments', 'early', 'during', 'operation',
#         'weekly', 'need', 'funding', '2012', '2011', 'refinancing', 'term',
#         'are', 'next', 'loans', 'euros', 'banks', 'limited', 'relatively',
#         'benefits', 'draghi', 'mario', 'recovery', 'rates', 'meeting',
#         'investors', 'economists', 'while', 'expected', 'order',
#         'securities', 'countries', 'bonds', 'ecb', 'polled', 'money',
#         'crisis', 'debt', 'zone', 'euro', 'european', 'very', 'might',
#         'suggests', 'still', 'could', 'not', 'will', 'cut', 'out', 'if',
#         'an', 'degree', 'forecast', 'currently', 'take', 'may', 'reuters',
#         'far', 'but', 'which', 'into', 'percent', 'after', 'friday',
#         'most', 'three', 'all', 'monday', 'economist', 'work', 'rose',
#         'below', 'interest', 'keep', 'long', 'easing', 'quantitative',
#         'called', 'so', 'months', 'other', 'they', 'were', 'when', 'be',
#         'bond', 'one', 'no', 'was', '175', 'back', 'week', 'more', 'time',
#         'inflation', 'low', 'as', 'even', 'sees', 'he', 'new', 'last',
#         'by', 'first', 'march', '18', 'market', 'growth', 'because',
#         'economy', 'high', 'is', 'for', 'rate', 'billion', '10', 'markets',
#         'least', 'or', 'some', 'that', 'fact', 'programme', 'stimulus',
#         'its', 'with', 'in', 'at', 'we', 'had', 'from', 'been', 'have',
#         'would', 'it', 'purchases', 'central', 'economic', 'recent',
#         'said', 'year', 'this', 'policy', 'on', 'president', 'bank',
#         'reserve', 'federal'], dtype='<U18'),
#  array(['above', 'showing', '40', 'usd', 'lower', 'sterling', 'slowdown',
#         'slowed', 'china', 'annual', 'separate', 'basis', 'exports',
#         'chinese', 'weekend', 'released', 'remained', 'sentiment',
#         'overall', 'portion', 'area', 'did', 'conditions', 'saying',
#         'unchanged', 'benchmark', 'continued', 'demand', 'resistance',
#         'pair', '48', 'gbp', 'eur', 'tightening', 'eased', 'expectations',
#         'stronger', 'broadly', 'lows', 'fell', 'pound', 'com', 'investing',
#         'hit', 'monetary', 'subdued', 'dollar', 'against', 'further',
#         'highest', 'large', 'up', 'support', 'over', 'set', 'are', 'loans',
#         'emergency', 'banks', 'left', 'down', 'thursday', 'fuelling',
#         'ecb', 'euro', 'european', 'session', 'concerns', 'also', 'not',
#         'second', 'largest', 'world', 'despite', 'after', 'friday',
#         'report', 'gains', 'monday', 'likely', 'find', 'well', 'interest',
#         'easing', 'jobs', 'be', 'one', 'was', 'increase', '000', '175',
#         'showed', 'week', 'february', 'added', 'inflation', 'low', 'as',
#         'outlook', 'new', 'month', 'last', 'since', 'by', '18', 'market',
#         'economy', 'for', 'rate', 'that', 'its', 'with', 'in', 'at',
#         'from', 'central', 'data', 'economic', 'year', 'this', 'policy',
#         'on', 'bank'], dtype='<U18'),
#  array(['wrap', 'international', 'overseeing', 'institutions', 'experts',
#         'concluded', 'hasn', 'aid', 'backing', 'hopes', 'till', 'island',
#         'approved', 'injection', 'fresh', 'expecting', 'review', 'whose',
#         'cyprus', 'ordinary', 'meet', 'minds', 'certainly', 'ukraine',
#         'accounts', 'foreign', 'transparency', 'framework', 'pushing',
#         'nights', 'ready', 'regulation', 'interested', 'anyone', 'list',
#         'late', 'third', 'greek', 'monetary', 'bailout', 'just',
#         'completed', 'commission', 'greece', 'finance', 'april', 'fund',
#         'final', 'reach', 'ministers', 'deal', 'won', 'required',
#         'resolution', 'then', 'capital', 'do', 'get', 'business', 'there',
#         'too', 'up', 'union', 'bloc', 'their', 'cash', 'return',
#         'financial', 'money', 'crisis', 'zone', 'euro', 'european', 'also',
#         'should', 'could', 'will', 'but', 'after', 'report', 'monday',
#         'work', 'long', 'be', 'was', 'week', 'more', 'new', 'is', 'for',
#         'some', 'that', 'its', 'in', 'had', 'from', 'been', 'central',
#         'isn', 'year', 'this', 'on', 'bank'], dtype='<U18'),
#  array(['condition', 'response', 'perfect', 'bounced', 'note', 'tuesday',
#         'decent', 'strength', 'ideal', 'watch', 'jobless', 'usual',
#         'light', 'calendar', 'situation', 'bad', 'disclose', 'knows',
#         'nobody', 'sheets', 'non', 'wrong', 'rest', 'model', 'forming',
#         'claims', 'elsewhere', 'prospects', 'actions', 'track',
#         'everything', 'clearly', 'moment', 'warranted', 'aren', 'cases',
#         'both', 'additional', 'creates', 'strengthen', 'starts', 'clear',
#         'executive', 'figure', 'complaint', 'derail', 'working', 'concept',
#         'interesting', 'excellence', 'fiscal', 'standard', 'gold',
#         'coming', 'eurozone', 'power', 'military', 'damaging', 'absence',
#         'expense', 'defense', 'rather', 'programs', 'social', 'public',
#         'spend', 'preferred', 'practice', 'honored', 'warships', 'sale',
#         'willing', 'possibility', 'says', 'merkel', 'believe', 'russia',
#         'sanctions', 'act', 'europeans', 'credible', 'tests', 'stress',
#         'mechanism', 'together', 'inability', 'sovereign', 'stopped',
#         'infrastructure', 'institutional', 'europe', 'worries',
#         'collection', 'issue', 'speculators', 'promote', 'classic',
#         'motive', 'suggestion', 'inevitable', 'along', 'fear', 'inspired',
#         'notice', 'australia', 'suppliers', 'pboc', 'instead', 'worrying',
#         'trust', 'repeatedly', 'notes', 'everyone', 'feb', 'dropped',
#         'falling', 'possibly', 'deficit', 'trade', 'focused',
#         'institutions', 'ukraine', 'foreign', 'list', 'usd', 'slowdown',
#         'china', 'exports', 'chinese', 'weekend', 'pressure', 'downward',
#         'put', 'happy', 'noyer', 'hit', 'small', 'deflation', 'news',
#         'dollar', 'against', 'target', 'short', 'finally', 'start', 'any',
#         'until', 'possible', 'french', 'currency', 'another', 'probably',
#         'failure', 'april', 'failing', 'jan', 'point', 'big', 'off',
#         'then', 'global', 'can', 'like', 'place', 'get', 'business',
#         'there', 'many', 'too', 'up', 'parliament', 'plan', 'attention',
#         'much', 'support', 'why', 'strong', 'early', 'way', 'weekly',
#         'bloc', 'times', 'day', 'their', 'need', 'little', '2012', 'over',
#         'are', 'loans', 'banks', 'draghi', 'thursday', 'countries', 'ecb',
#         'money', 'crisis', 'debt', 'euro', 'european', 'you', 'very', 'go',
#         'balance', 'how', 'should', 'environment', 'could', 'not', 'noted',
#         'end', 'will', 'real', '2013', 'if', 'an', 'take', 'may', 'same',
#         'far', 'world', 'sales', 'retail', 'but', 'meanwhile', 'all',
#         'bit', 'latest', 'top', 'work', 'before', 'well', 'long', 'so',
#         'other', 'were', 'about', 'when', 'be', 'one', 'no', 'followed',
#         'back', 'week', 'than', 'us', 'time', 'inflation', 'as', 'outlook',
#         'he', 'she', 'since', 'by', 'march', 'growth', 'has', 'economy',
#         'trying', 'either', 'pretty', 'is', 'for', 'rate', 'what', 'least',
#         'or', 'some', 'give', 'that', 'its', 'with', 'in', 'at', 'we',
#         'from', 'been', 'have', 'it', 'data', 'said', 'this', 'policy',
#         'on', 'bank', 'reserve'], dtype='<U18'),
#  array(['comments', 'conclusion', 'declined', 'tends', 'development',
#         'input', 'governor', 'energy', 'transit', 'disruption', 'concern',
#         'softer', 'prices', 'oil', 'debacle', 'ukrainian', 'approach',
#         'looks', 'clients', 'write', 'flow', 'haven', 'trigger',
#         'extension', 'appetite', 'potential', 'enter', 'tried', 'turning',
#         'seizing', 'region', 'crimea', 'tightened', 'forces', 'russian',
#         'pro', 'grip', 'offshore', '250', 'kingdom', 'united',
#         'pronounced', 'retreat', 'began', 'steady', 'accounted', 'office',
#         'sunday', 'quarterly', 'developments', 'activity', 'continuing',
#         'contracts', 'border', 'cross', 'looking', 'reading', '13',
#         'advanced', 'revealed', 'firm', 'research', 'conducted', '35',
#         'hits', 'supportive', 'widening', 'believes', 'strategist', 'citi',
#         'payments', 'resulting', 'tax', 'consumption', 'demands', 'rush',
#         '345', 'widened', 'owed', 'deterioration', 'number', 'headline',
#         'spending', 'investment', 'estimate', 'quarter', 'fourth',
#         'annualized', 'expanded', 'composite', 'shanghai', 'seng', 'hang',
#         'kong', 'hong', '225', 'nikkei', 'japanese', 'dax', 'exception',
#         'mostly', 'yen', 'flat', 'changed', 'treasury', '500', 'north',
#         'begin', 'quiet', '03', 'trading', 'rebounded', 'metal',
#         'reaction', 'overnight', 'slid', 'futures', 'copper', 'drop',
#         'decline', 'marking', 'producer', 'rise', 'consensus', 'missing',
#         'slowing', 'index', 'consumer', 'q1', 'gdp', 'yuan', 'negative',
#         'disappointing', 'actual', 'belief', 'inflated', 'holiday',
#         'lunar', 'owes', 'causing', 'imports', 'logging', 'earlier',
#         'tumble', 'here', 'morning', 'good', 'sources', 'diplomatic',
#         'nation', 'opec', 'south', 'dead', 'venezuela', 'unrest',
#         'discuss', 'american', 'latin', '2014', 'square', 'protest',
#         'burning', 'sets', 'anti', 'note', 'strength', 'situation', 'non',
#         'claims', 'moment', 'warranted', 'cases', 'both', 'additional',
#         'creates', 'strengthen', 'standard', 'military', 'rather', 'says',
#         'russia', 'deficit', 'trade', 'international', 'review', 'meet',
#         'ukraine', 'foreign', 'pushing', 'lower', 'china', 'exports',
#         'chinese', 'weekend', 'area', 'fell', 'pound', 'pressure',
#         'downward', 'happy', 'noyer', 'christian', 'member', 'japan',
#         'late', 'third', 'council', 'governing', 'record', 'our', 'news',
#         'slightly', 'dollar', 'against', 'price', 'published', 'action',
#         'however', 'dip', 'say', 'any', 'possible', 'highest', 'risk',
#         'across', 'confidence', 'higher', 'april', 'investor', 'ministers',
#         'point', 'now', '20', 'close', 'credit', 'safe', 'business',
#         'better', 'remains', 'up', 'much', 'germany', 'during', 'banking',
#         'survey', '14', 'their', 'need', 'little', '2011', 'trillion',
#         'over', 'are', 'next', 'banks', 'left', 'lending', 'down',
#         'meeting', 'announce', 'economists', 'ecb', 'zone', 'euro',
#         'european', 'know', 'you', 'very', 'balance', 'also', 'suggests',
#         'still', 'not', 'will', 'current', 'announced', '2013',
#         'accelerated', 'forecasts', 'out', 'an', 'near', 'forecast',
#         'ongoing', 'account', 'take', 'reuters', 'largely', 'despite',
#         'which', 'meanwhile', 'positions', 'after', 'friday', 'report',
#         'government', 'most', 'france', 'only', 'suggest', 'latest',
#         'official', 'likely', 'before', 'rose', 'falls', 'interest',
#         'main', 'so', 'months', 'previous', 'though', 'were', 'when', 'be',
#         'january', 'monthly', 'was', 'increase', 'revised', 'gain', 'back',
#         'week', 'february', 'than', 'more', 'inflation', 'as', 'outlook',
#         'new', 'month', 'last', 'since', 'by', 'first', 'march', '18',
#         'market', 'open', 'growth', 'weakness', 'has', 'economy', 'high',
#         'is', 'for', 'rate', 'billion', '10', 're', 'what', 'markets',
#         'least', 'or', 'important', 'that', 'its', 'with', 'interview',
#         'television', 'bloomberg', 'in', 'at', 'we', 'from', 'would', 'it',
#         'pace', 'isn', 'data', 'economic', 'recent', 'said', 'year',
#         'this', 'policy', 'on', 'who', 'bank', 'paris'], dtype='<U18'),
#  array(['precisely', 'encouraged', 'rbs', 'escape', 'dangerous', 'cost',
#         '2008', 'industry', 'total', '297', 'rapidly', 'devoted',
#         'belgium', '1990s', '95', '600', 'ratio', 'haircut', 'decided',
#         'organizations', 'mass', 'cypriot', 'multi', 'four', 'leaving',
#         'debts', 'offered', 'yield', 'billions', 'decade', 'linked',
#         'revenues', 'several', 'amounts', 'huge', 'allowed', 'poor',
#         'home', 'load', 'enabled', 'policies', 'side', 'feedback',
#         'respectively', '45', '52', '62', 'increased', '355', 'risen',
#         'holdings', 'being', 'shareholders', 'private', 'save', 'funds',
#         'deep', 'hide', 'firms', 'between', 'carry', 'mere', 'facility',
#         'longer', 'plug', 'opportunity', 'welcomed', 'primary', 'profit',
#         'yielded', 'pump', 'recently', 'cheap', 'providing', 'having',
#         'blamed', 'pool', 'sector', 'pension', 'healthy', 'develop',
#         'country', 'once', 'traditionally', 'somebody', 'often', 'analyst',
#         'analysis', 'weight', 'partly', '2010', 'updated', 'chose',
#         'weighted', 'making', 'incentives', 'regulations', '1980s',
#         'heavily', 'emerging', 'regulators', 'morgan', 'jp', 'buyers',
#         'alternative', 'simply', 'encourage', 'tied', 'hands', 'warn',
#         'analysts', 'nexus', 'terms', 'keen', 'although', 'entire',
#         'pushed', 'already', 'link', 'ailing', 'using', 'exposed',
#         'concern', 'region', 'began', '13', 'strategist', 'number', 'gdp',
#         'negative', 'sheets', 'aren', 'cases', 'standard', 'eurozone',
#         'public', 'sovereign', 'europe', 'falling', 'trade', 'foreign',
#         'lower', 'annual', 'increasingly', 'late', 'worth', 'few', 'best',
#         'deutsche', 'greek', '25', 'forced', 'our', 'bailout', 'just',
#         'full', 'used', 'build', 'say', 'any', 'issues', 'loan', 'every',
#         'roughly', 'italy', 'exposure', 'relative', 'highest', 'assets',
#         'equivalent', '75', 'greece', 'risk', 'buy', 'break', 'finance',
#         'italian', 'spanish', 'political', 'across', 'higher', 'shut',
#         'spain', 'today', 'rules', 'losses', 'including', 'purpose',
#         'impose', 'yet', 'now', 'exactly', 'global', '20', 'can',
#         'growing', 'national', 'easy', 'restructuring', 'capital',
#         'credit', 'years', 'do', 'problem', 'there', 'many', 'loop', 'up',
#         'diluted', 'bailing', 'want', 'much', 'systems', 'governments',
#         'them', 'net', 'insurance', 'early', 'way', 'banking', 'borrow',
#         'extra', 'their', 'need', 'cash', 'those', 'lenders', '2012',
#         '2011', 'operations', 'refinancing', 'term', 'trillion', 'over',
#         'are', 'less', 'loans', 'emergency', 'euros', 'banks', 'bolster',
#         'hold', 'event', 'rates', 'lending', 'system', 'financial',
#         'liquidity', 'investors', 'while', 'order', 'securities',
#         'countries', 'bonds', 'bought', 'ecb', 'money', 'crisis', 'debt',
#         'euro', 'european', 'levels', 'know', 'you', 'balance', 'reduce',
#         'how', 'also', 'still', 'not', 'end', 'will', 'real', 'half',
#         'out', 'if', 'right', 'an', 'increasing', 'future', 'reuters',
#         'policymakers', 'but', 'which', 'search', 'into', 'percent',
#         'after', 'government', 'according', 'effect', 'most', 'these',
#         'only', 'latest', '2006', 'before', 'figures', 'zero', 'interest',
#         'weak', 'previous', 'they', 'were', 'about', 'asked', 'when', 'be',
#         'past', 'reason', 'one', 'estimated', 'initially', 'was',
#         'increase', '129', 'than', 'more', 'added', 'time', 'low', 'as',
#         'even', 'last', 'since', 'by', 'first', 'committee', 'because',
#         'has', 'economy', 'is', 'for', 'billion', '10', 'doing', 'what',
#         'markets', 'or', 'some', 'that', 'fact', 'its', 'with', 'in', 'at',
#         'we', 'had', 'from', 'been', 'have', 'would', 'it', 'purchases',
#         'central', 'change', 'enough', 'isn', 'data', 'recent', 'said',
#         'year', 'this', 'on', 'who', 'bank', 'london'], dtype='<U18'),
#  array(['84', 'received', '30', '09', '29', '103', '05', '07', '94', '102',
#         'touched', '192', 'upon', 'impact', 'adverse', 'causes', 'usually',
#         'larger', 'import', 'export', 'fuel', 'weaker', 'factors',
#         'anticipated', '38', '39', 'self', 'becomes', 'll', 'hire',
#         'income', 'means', 'commented', 'inc', 'joe', 'fundamentals',
#         'housing', 'temperatures', 'normal', 'storms', 'upbeat',
#         'suggested', 'job', 'workforce', 'payrolls', 'add', 'managed',
#         'statistics', 'bureau', 'supported', 'greenback', 'june', 'surged',
#         'services', 'jumped', 'addition', 'netherlands', 'driven',
#         'mainly', 'weeks', 'define', 'uses', 'advance', 'alcohol',
#         'tobacco', 'food', 'items', 'volatile', 'core', 'projections',
#         'grew', 'unexpectedly', 'prompted', 'reported', 'average', '2015',
#         'living', 'estimates', 'gradually', 'boosting', 'following',
#         'maintained', '6th', 'objective', 'affect', 'addressed',
#         'exporters', 'challenging', 'goods', 'strongest', 'encountered',
#         '7th', 'found', 'adding', '12', 'daily', 'gmt', '27', 'created',
#         'strengthening', 'october', 'highs', 'retreated', 'cost',
#         'decided', 'four', 'increased', 'risen', 'country', 'analysts',
#         'tends', 'development', 'input', 'energy', 'prices', 'oil',
#         'united', 'reading', '35', 'widened', 'spending', 'quarter',
#         'fourth', 'annualized', 'changed', '500', '03', 'rebounded',
#         'rise', 'consumer', 'imports', 'good', 'nation', 'elsewhere',
#         'everything', 'moment', 'warranted', 'cases', 'both', 'additional',
#         'creates', 'strengthen', 'figure', 'deficit', 'trade', 'experts',
#         'usd', 'slowed', 'sentiment', 'overall', 'area', 'saying',
#         'benchmark', 'demand', 'resistance', 'pair', 'eur', 'stronger',
#         'pressure', 'downward', 'happy', 'noyer', 'christian', 'hit',
#         'member', 'especially', 'council', 'governing', 'deutsche', '25',
#         'record', 'deflation', 'conference', 'seemed', 'dollar', 'against',
#         'target', 'price', '2016', '76', 'decision', 'wider', 'november',
#         'italy', '75', 'risks', 'currency', 'across', 'reach', 'losses',
#         'such', 'stability', 'parts', 'capital', 'business', 'problem',
#         'remains', 'states', 'up', 'common', 'much', 'previously',
#         'germany', 'support', 'deposit', 'during', 'remaining', 'amount',
#         'day', 'little', '2011', 'return', 'are', '11', 'less',
#         'predicted', 'draghi', 'mario', 'chief', 'recovery', 'fragile',
#         'lending', 'while', 'expected', 'securities', 'september', 'ecb',
#         'zone', 'euro', 'european', 'session', 'very', 'balance',
#         'ultimately', 'also', 'still', 'not', 'will', 'cut', 'output',
#         'half', 'product', 'domestic', 'gross', 'forecasts', 'behind',
#         'an', 'accelerate', 'may', 'same', 'manufacturing', 'but', 'which',
#         'americans', 'meanwhile', 'after', 'friday', 'report', 'according',
#         'most', 'december', 'france', 'only', 'labor', 'likely', 'eastern',
#         'economist', 'find', 'couldn', 'entered', 'people', 'before',
#         'rose', 'below', 'zero', 'interest', 'main', 'keep', 'easing',
#         'so', 'press', 'months', 'previous', 'they', 'were', 'jobs',
#         'about', 'when', 'be', 'january', 'past', 'each', 'was',
#         'increase', '129', 'revised', '000', '175', 'week', 'february',
#         'projected', 'than', 'workers', 'more', 'added', 'employers', 'us',
#         'time', 'inflation', 'low', 'unemployment', 'as', 'outlook',
#         'york', 'new', 'month', 'last', 'since', 'by', 'march', '18',
#         'growth', 'winter', 'has', 'economy', 'high', 'for', 'rate',
#         'billion', 're', 'important', 'that', 'its', 'with', 'interview',
#         'television', 'bloomberg', 'in', 'faster', 'at', 'we', 'had',
#         'from', 'been', 'have', 'it', 'central', 'isn', 'data', 'economic',
#         'encouraging', 'recent', 'said', 'year', 'this', 'on', 'president',
#         'bank', 'paris'], dtype='<U18'),
#  array(['comment', 'external', 'models', 'within', 'valued', 'collateral',
#         'valuations', 'source', 'fall', 'methods', 'lingering', 'deciding',
#         'examined', 'date', 'insight', 'explicit', 'tested', '128',
#         'details', 'knowledge', 'test', 'announcement', 'revelations',
#         'defined', 'dublin', 'laura', 'becomes', 'estimates', 'created',
#         'billions', 'being', 'declined', 'sources', '2014', 'tuesday',
#         'bad', 'sheets', 'tests', 'review', 'stance', 'against', 'short',
#         'decide', 'any', 'november', 'loan', 'confidence', 'restore',
#         'books', 'clean', 'rules', 'losses', 'investor', 'turned',
#         'matter', 'use', 'done', 'supervisor', 'capital', 'require', 'up',
#         'problems', 'extra', 'their', 'need', 'those', 'set', 'are',
#         'loans', 'euros', 'banks', 'ecb', 'zone', 'euro', 'european',
#         'biggest', 'balance', 'how', 'also', 'not', 'will', 'if', 'told',
#         'an', 'must', 'reuters', 'largest', 'most', 'three', 'before',
#         'they', 'be', 'january', 'two', 'one', 'new', 'by', 'march', 'has',
#         'whether', 'for', '10', 'some', 'give', 'that', 'with', 'in',
#         'had', 'been', 'it', 'central', 'said', 'year', 'on', 'bank'],
#        dtype='<U18'),
#  array(['owner', 'marked', 'water', 'copies', '100', 'fines', 'leaks',
#         'care', 'vehicles', 'special', 'deals', 'acquired', 'estate',
#         'difficult', 'level', 'treatment', 'ones', 'brand', 'rounds',
#         'assessment', 'ireland', 'behalf', 'carrying', 'thing',
#         'probability', 'status', 'fallen', 'distress', 'corporate',
#         'evidence', 'indicators', 'impairment', 'unlikely', 'performing',
#         'rule', 'simple', 'include', 'watched', 'closely', 'pages', '300',
#         'nearly', 'laid', 'pointing', 'guidelines', 'reasonable',
#         'penalties', 'agreements', 'disclosure', 'detailing', 'document',
#         'correctly', 'initial', 'carried', 'range', 'areas', 'key', 'hard',
#         'comment', 'external', 'models', 'within', 'valued', 'collateral',
#         'valuations', 'source', 'fall', 'examined', 'date', 'insight',
#         'explicit', 'tested', '128', 'details', 'knowledge', 'test',
#         'announcement', 'revelations', 'defined', 'dublin', 'laura',
#         'becomes', 'weeks', 'estimates', 'created', 'billions', 'several',
#         'holdings', 'being', 'private', 'declined', 'approach', 'tried',
#         'looking', '13', 'investment', 'changed', 'sources', '2014',
#         'sets', 'tuesday', 'bad', 'sheets', 'non', 'strengthen', 'coming',
#         'rather', 'tests', 'stress', 'review', 'list', 'late', 'third',
#         'stance', 'view', 'against', 'short', 'full', 'signed', 'taken',
#         'decision', 'any', 'complex', 'become', 'amongst', 'november',
#         'loan', 'assets', 'name', 'default', 'treated', 'confidence',
#         'restore', 'books', 'clean', 'higher', 'rules', 'losses',
#         'investor', 'deal', 'face', 'such', 'now', 'supervisors', 'use',
#         'group', 'done', 'can', 'supervisor', 'like', 'things', 'national',
#         'equity', 'capital', 'broad', 'require', 'up', 'much', 'them',
#         'got', 'idea', 'days', 'prevent', 'way', 'problems', '90',
#         'provide', 'extra', 'their', 'need', 'beyond', 'those', 'over',
#         'set', 'are', 'loans', 'euros', 'banks', 'left', 'financial',
#         'while', 'value', 'through', 'ecb', 'crisis', 'zone', 'euro',
#         'european', 'biggest', 'very', 'sheet', 'balance', 'how', 'also',
#         'still', 'not', 'will', 'real', '2013', 'second', 'out', 'if',
#         'told', 'an', 'must', 'future', 'reuters', 'aside', 'largest',
#         'creating', 'most', 'three', 'all', 'suggest', 'likely', 'force',
#         'before', 'well', 'previous', 'other', 'they', 'though', 'when',
#         'be', 'january', 'two', 'one', 'was', '000', 'than', 'more', 'as',
#         'even', 'new', 'since', 'by', 'first', 'march', 'has', 'whether',
#         'is', 'for', 'billion', '10', 'what', 'some', 'give', 've', 'that',
#         'its', 'with', 'in', 'at', 'had', 'from', 'been', 'have', 'would',
#         'it', 'central', 'said', 'year', 'on', 'bank'], dtype='<U18'),
#  array(['king', 'larry', 'thomas', 'reporting', 'greater', 'kept',
#         'conventional', 'solely', 'guidance', 'period', 'extended',
#         'members', 'background', 'vulnerable', 'drive', 'territory',
#         'positive', 'firmly', 'spiral', 'described', 'held', 'excessive',
#         'slowly', 'cited', 'commonly', 'achievement', 'threatens',
#         'active', 'warned', 'threat', 'adds', 'pressures', 'permanent',
#         'unlikely', 'source', 'explicit', 'details', 'defined', 'impact',
#         '39', 'statistics', 'adding', 'deep', 'longer', 'governor',
#         'prices', 'forces', 'steady', 'consumption', 'investment',
#         'negative', 'strength', 'working', 'lower', 'did', 'unchanged',
#         'expectations', 'editing', 'downward', 'noyer', 'christian',
#         'appreciation', 'relying', 'major', 'tool', 'late', 'council',
#         'governing', 'remain', 'deflation', 'weighing', 'monetary',
#         'conference', 'dollar', 'against', 'target', 'price', 'action',
#         'slack', 'short', 'available', 'under', 'wider', 'highest', 'risk',
#         'french', 'economies', 'agency', 'today', 'limits', 'such', 'off',
#         'where', 'influence', 'stability', 'forward', 'eu', 'close',
#         'indeed', 'do', 'there', 'many', 'see', 'strong', 'days', 'expect',
#         'provide', 'their', '2011', 'term', 'are', 'less', 'banks',
#         'relatively', 'left', 'rates', 'financial', 'thursday',
#         'countries', 'ecb', 'debt', 'zone', 'euro', 'made', 'european',
#         'levels', 'go', 'without', 'should', 'could', 'not', 'current',
#         'told', 'an', 'currently', 'reuters', 'world', 'but', 'meant',
#         'percent', 'after', 'all', 'france', 'monday', 'rose', 'below',
#         'well', 'interest', 'keep', 'called', 'were', 'past', 'estimated',
#         'was', 'back', 'february', 'than', 'more', 'added', 'time',
#         'inflation', 'low', 'as', 'even', 'sees', 'he', 'new', 'since',
#         'by', 'march', 'because', 'has', 'economy', 'is', 'for', '10',
#         'what', 'or', 'that', 'its', 'with', 'in', 'at', 'had', 'from',
#         'would', 'it', 'central', 'recent', 'said', 'policy', 'on', 'bank',
#         'paris'], dtype='<U18'),
#  array(['reverse', 'careful', 'calls', 'carefully', 'consideration',
#         'importantly', 'noting', 'discussion', 'facing', 'insisted', 'shy',
#         'lowered', 'style', 'raising', 'challenge', 'produces', 'direct',
#         'definition', 'closer', 'stayed', 'easier', 'mr', 'adjustments',
#         'competitive', 'strategies', 'adjustment', 'wages', 'increases',
#         'slow', 'territory', 'positive', 'firmly', 'warned', 'difficult',
#         'ones', 'assessment', 'watched', 'hard', 'within', 'fall',
#         'impact', 'services', '2015', 'gradually', 'goods', 'precisely',
#         'recently', 'country', 'analysts', 'prices', 'write', 'rise',
#         'earlier', 'situation', 'lower', 'slowed', 'overall', 'area',
#         'expectations', 'com', 'exchange', 'noyer', 'christian',
#         'appreciation', 'member', 'japan', 'small', 'council', 'governing',
#         'remain', 'taking', 'measure', 'deflation', 'medium', 'reasons',
#         'capacity', 'post', 'target', 'price', '2016', 'however', 'short',
#         'just', 'fully', 'under', 'process', 'become', 'others', 'risks',
#         'currency', 'today', 'reach', 'including', 'such', 'stability',
#         'multiple', 'needs', 'necessary', 'close', 'run', 'years', 'place',
#         'make', 'problem', 'there', 'serious', 'many', 'bloc', 'need',
#         'term', 'over', 'are', 'order', 'countries', 'ecb', 'zone', 'euro',
#         'made', 'european', 'wsj', 'very', 'balance', 'also', 'should',
#         'still', 'not', 'real', 'if', 'panel', 'told', 'an', 'increasing',
#         'forecast', 'but', 'into', 'most', 'december', 'pointed', 'france',
#         'monday', 'zero', 'main', 'so', 'they', 'be', 'no', 'than', 'more',
#         'inflation', 'low', 'as', 'even', 'he', 'by', 'because', 'signs',
#         'has', 'is', 'for', 'rate', 'some', 'important', 'that', 'its',
#         'with', 'in', 'at', 'from', 'would', 'it', 'central', 'pace',
#         'isn', 'recent', 'said', 'year', 'this', 'on', 'bank', 'paris'],
#        dtype='<U18'),
#  array(['eventually', 'contributions', 'accessible', 'shared', 'resolved',
#         'fate', 'accommodate', 'achieve', 'involved', 'ground', 'delayed',
#         'legislative', 'complete', '28', 'represented', 'stage', 'crucial',
#         'single', 'triggered', 'households', 'businesses', 'thorough',
#         'key', 'nation', 'bad', 'clear', 'executive', 'eurozone',
#         'mechanism', 'sovereign', 'member', 'stay', 'filled', 'soon',
#         'build', 'say', 'declare', 'institution', 'arguing', 'involvement',
#         'quickly', 'commission', 'signed', 'board', 'taken', 'decision',
#         'closing', 'process', 'disagree', 'wants', 'november', 'takes',
#         'recession', 'raise', 'efforts', 'finance', 'political', 'another',
#         'confidence', 'restore', 'books', 'clean', 'probably', 'law',
#         'april', 'mid', 'sitting', 'fund', 'agency', 'agreement', 'talks',
#         'pay', 'pot', 'rules', 'mean', 'step', 'final', 'span',
#         'negotiations', 'failing', 'wind', 'reach', 'try', 'ministers',
#         'deal', 'won', 'own', 'now', 'resolution', 'global', 'can',
#         'solution', 'supervisor', 'things', 'authorities', 'national',
#         'eu', 'close', 'capital', 'around', 'don', 'problem', 'there',
#         'states', 'up', 'parliament', 'want', 'common', 'different',
#         'governments', 'trouble', 'early', 'days', 'agreed', 'banking',
#         'union', 'seven', 'bloc', 'those', 'set', 'next', 'loans', 'banks',
#         'lending', 'down', 'financial', 'boost', 'meeting', 'countries',
#         'ecb', 'money', 'crisis', 'debt', 'european', 'very', 'go',
#         'reduce', 'how', 'also', 'should', 'will', 'current', 'if', 'an',
#         'must', 'policymakers', 'but', 'meant', 'into', 'prepared',
#         'three', 'all', 'december', 'only', 'official', 'find', 'entered',
#         'before', 'well', 'show', 'long', 'months', 'other', 'they', 'be',
#         'one', 'no', 'back', 'week', 'more', 'time', 'as', 'new', 'last',
#         'by', 'has', 'direction', 'is', 'for', 'least', 'or', 'that',
#         'its', 'in', 'at', 'we', 'from', 'been', 'have', 'would', 'it',
#         'central', 'enough', 'said', 'year', 'on', 'bank'], dtype='<U18'),
#  array(['distribution', 'christopher', 'reports', 'please', 'massive',
#         'wouldn', 'absent', 'boe', 'exist', 'chips', 'deliberate',
#         'necessity', 'momentum', 'present', 'frankly', 'quite', 'stands',
#         'stuck', 'health', 'confusion', 'unnecessary', 'unknown',
#         'discovered', 'results', 'announcing', 'improved', 'generally',
#         'signal', 'modest', 'surveys', 'her', 'buoyed', 'inject', 'opened',
#         'door', 'window', 'realize', 'helped', 'constructive', 'came',
#         '08', 'pack', 'conflict', 'seemingly', 'tensions', 'cooling',
#         'mixed', 'basket', 'bias', 'bullish', 'breakout', 'favor', 'forex',
#         'neutral', 'eventually', 'period', 'level', 'pointing', 'fall',
#         '38', 'means', 'payrolls', 'surged', 'highs', 'multi', 'policies',
#         'being', 'between', 'recently', 'once', 'analyst', 'simply',
#         'prices', 'appetite', 'potential', 'began', 'consumption',
#         'overnight', 'consumer', 'negative', 'strength', 'sheets', 'non',
#         'wrong', 'elsewhere', 'clear', 'standard', 'coming', 'military',
#         'act', 'tests', 'stress', 'sovereign', 'europe', 'instead',
#         'review', 'ready', 'list', 'conditions', 'continued', 'pair',
# ...
#  array(['sharleen', 'bonding', 'fairytale', 'favour', 'bikini', 'charming',
#         'whispered', 'microphones', 'saint', 'finalist', 'sealed', 'beau',
#         'contestant', 'lowe', 'giudici', 'dorfman', 'andi', 'marry',
#         'lane', 'diamond', 'sacramento', 'helicopter', 'lucia', 'crawley',
#         'runner', 'ferrell', 'bachelorette', 'camila', 'nurse',
#         'pediatric', 'clare', 'nikki', 'galavis', 'pablo', 'heartbroken',
#         'kisses', 'wore', 'rude', 'refuses', 'adorable', 'happiness',
#         'blonde', 'boyfriend', 'contestants', 'daddy', 'chooses', 'blind',
#         'feelings', 'girls', 'sexual', 'confessed', 'kansas', 'boat',
#         'awkward', 'loving', 'propose', 'gonna', 'romantic', 'couch',
#         'wife', 'missouri', 'husband', 'appalling', 'girl', 'knee', 'abc',
#         'goodbye', 'parents', 'chosen', 'hooking', 'loves', 'pressed',
#         'marriage', 'fantasy', 'wearing', 'ears', 'families', 'lover',
#         'ring', 'ditched', 'replied', 'crying', 'kissed', 'walking',
#         'chris', 'ear', 'boring', 'shoulder', 'length', 'football',
#         'admitting', 'hugging', 'studio', 'finale', 'awaited', 'dubbed',
#         'town', 'offensive', 'storm', 'twelve', 'honestly', 'presentation',
#         'instantly', 'wedding', 'answering', 'bachelor', 'picks', 'upset',
#         'leaned', 'harrison', 'beautiful', 'sean', 'fun', 'child',
#         'object', 'opted', 'suite', 'neil', 'father', 'destination',
#         'disastrous', 'harm', 'insulting', 'ally', 'relationships', 'mom',
#         'uncomfortable', 'excited', 'engagement', 'women', 'behaviour',
#         'dress', 'moments', 'drama', 'beauty', 'cameras', 'repeated',
#         'respect', 'declaration', 'towards', 'confront', 'floor',
#         'frontrunner', 'choosing', 'kiss', 'hug', 'mouth', 'juan', 'beach',
#         'seat', 'spends', 'twist', 'wait', 'journey', 'devastated',
#         'famously', 'sit', 'son', 'professional', 'speaking', 'host',
#         'city', 'hear', 'mum', 'interviews', 'woman', 'forever', 'awful',
#         'children', 'thousand', 'threw', 'cry', 'dream', 'stick', 'feels',
#         'listening', 'surprised', 'ing', 'contain', 'confronted',
#         'admitted', 'wow', 'attempted', 'word', 'unlike', 'pocket', 'laws',
#         'mother', 'tears', 'broke', 'controversial', 'questioning',
#         'closure', 'planning', 'answers', 'silence', 'dates', 'prince',
#         'death', 'letting', 'refused', 'relationship', 'hearing',
#         'controversy', 'shocked', 'someone', 'road', 'caught', 'hot',
#         'accept', 'respond', 'daughter', 'named', 'appeared', 'friend',
#         'avoided', 'maybe', 'expectation', 'thinks', 'family', 'sweet',
#         'met', 'hoped', 'chance', 'stood', 'sorts', 'myself', 'catherine',
#         'cent', 'talk', 'ask', 'somehow', 'merely', 'occasions', 'hated',
#         'mind', 'baby', 'catch', 'hotel', 'recalled', 'arrived', 'shock',
#         'couple', 'surrounding', 'telling', 'cloud', 'winning', 'life',
#         'else', 'assured', 'seeing', 'read', 'stepped', 'felt', 'calm',
#         'bed', 'am', 'events', 'tough', 'hope', 'accompanied', 'warnings',
#         'blue', 'season', 'black', '32', 'enjoyed', 'repeat', 'live',
#         'speak', 'viewers', 'awesome', 'absolutely', 'amazing', 'fighting',
#         'watching', 'anything', 'man', 'fantastic', 'loved', 'imagine',
#         'vying', 'seem', 'engaged', 'let', 'me', 'surprise', 'kind',
#         'thank', 'crazy', 'spot', 'yes', 'audience', 'night', 'went',
#         'ever', 'love', 'dumped', 'thought', 'closed', 'box', 'definitely',
#         'looked', 'getting', 'reality', 'california', 'feel',
#         'competition', 'piece', 'tv', 'questions', 'walked', '26',
#         'responded', 'lot', 'directly', 'sure', 'your', 'comes', 'ended',
#         'particular', 'calling', 'makes', 'unfortunately', 'great', 'guy',
#         'success', 'returned', 'letter', 'line', 'turn', 'words', 'shares',
#         'hurt', 'considered', 'picture', 'really', 'player', 'him', 'old',
#         'neither', 'his', 'rejected', 'present', 'quite', 'confusion',
#         'her', 'came', 'shared', 'complete', 'stage', 'single', 'insisted',
#         '100', 'special', 'thing', 'comment', 'date', 'explicit',
#         'anticipated', 'upbeat', 'managed', 'following', 'addressed',
#         'adding', 'four', 'leaving', 'offered', 'several', 'home', 'side',
#         'being', 'private', 'deep', 'having', 'once', 'often', 'chose',
#         'warn', 'keen', 'already', 'conclusion', 'pro', 'began', 'looking',
#         'spending', 'changed', 'reaction', 'missing', 'earlier', 'here',
#         'response', 'perfect', 'usual', 'situation', 'bad', 'non', 'wrong',
#         'track', 'everything', 'clearly', 'moment', 'both', 'figure',
#         'says', 'stress', 'together', 'inability', 'repeatedly',
#         'everyone', 'falling', 'possibly', 'meet', 'certainly', 'pushing',
#         'ready', 'did', 'saying', 'stronger', 'put', 'happy', 'handed',
#         'especially', 'few', 'best', 'hoping', 'throughout', 'spent',
#         'stay', 'our', 'opening', 'seemed', 'took', 'however', 'finally',
#         'just', 'full', 'soon', 'used', 'say', 'hand', 'decision', 'any',
#         'heart', 'until', 'possible', 'wants', 'giving', 'every', 'across',
#         'another', 'law', 'today', 'mean', 'final', 'win', 'something',
#         'turned', 'won', 'alone', 'face', 'such', 'own', 'certain',
#         'nothing', 'does', 'per', 'yet', 'now', 'big', 'luck', 'off',
#         'again', 'where', 'then', 'use', 'proposal', 'done', 'can',
#         'easily', 'like', 'things', 'tell', 'going', 'easy', 'years',
#         'around', 'do', 'place', 'get', 'don', 'better', 'think', 'many',
#         'too', 'understand', 'see', 'doesn', 'up', 'hook', 'want', 'didn',
#         'much', 'previously', 'different', 'why', 'lost', 'them', 'able',
#         'got', 'days', 'during', 'way', 'wanted', 'needed', 'wasn', 'come',
#         'nine', 'day', 'their', 'beyond', 'ride', 'over', 'return', 'next',
#         'left', 'down', 'meeting', 'while', 'offering', 'through', 'seen',
#         'made', 'stop', 'answer', 'question', 'know', 'never', 'you', 'go',
#         'without', 'how', 'also', 'perhaps', 'history', 'still', 'could',
#         'not', 'later', 'end', 'will', 'announced', 'out', 'if', 'leave',
#         'right', 'told', 'an', 'away', 'future', 'gave', 'same', 'but',
#         'which', 'meanwhile', 'after', 'effect', 'part', 'most', 'these',
#         'all', 'only', 'monday', 'story', 'former', 'find', 'couldn',
#         'people', 'before', 'rose', 'show', 'so', 'months', 'they',
#         'though', 'were', 'about', 'asked', 'when', 'be', 'two', 'each',
#         'bond', 'reason', 'one', 'saw', 'no', 'initially', 'was', 'back',
#         'starting', 'than', 'more', 'added', 'time', 'as', 'even', 'he',
#         'new', 'last', 'she', 'by', 'first', 'setting', 'because', 'has',
#         'whether', 'trying', 'either', 'pretty', 'is', 'for', 'doing',
#         're', 'what', 'or', 'some', 've', 'that', 'fact', 'its', 'fed',
#         'with', 'interview', 'in', 'at', 'we', 'had', 'my', 'from', 'been',
#         'have', 'would', 'it', 'enough', 'isn', 'said', 'year', 'this',
#         'on', 'who'], dtype='<U18'),
#  array(['assures', 'hyperactive', 'traits', 'nelly', 'pabs', 'gesture',
#         'stepmom', 'bachelors', 'rodolfo', 'cousin', 'lady', 'camila',
#         'nurse', 'clare', 'nikki', 'pablo', 'rude', 'dad', 'pink',
#         'flower', 'daddy', 'feelings', 'applause', 'ladies', 'honesty',
#         'lap', 'responds', 'problematic', 'freely', 'lovers',
#         'acknowledging', 'warmth', 'arrives', 'determined', 'mental',
#         'prize', 'complaining', 'begging', 'nasty', 'seconds', 'smile',
#         'afraid', 'bachelor', 'personality', 'beautiful', 'wish',
#         'bearing', 'father', 'bright', 'receives', 'rejects', 'saul',
#         'mom', 'asks', 'ours', 'dress', 'flowers', 'guess', 'la', 'mouth',
#         'juan', 'latino', 'papa', 'son', 'hear', 'cry', 'rough', 'okay',
#         'existence', 'andy', 'adventure', 'embrace', 'angry', 'feed',
#         'tears', 'honest', 'relationship', 'lying', 'hearing', 'someone',
#         'hot', 'accept', 'proposes', 'behavior', 'reactions', 'thinks',
#         'tells', 'type', 'brought', 'space', 'practically', 'mind',
#         'telling', 'wins', 'sometimes', 'life', 'happened', 'eye', 'am',
#         'nervous', 'season', 'always', 'settings', 'fantastic', 'let',
#         'me', 'team', 'yes', 'audience', 'love', 'changing', 'tv', 'walk',
#         'learned', 'various', 'fair', 'great', 'guy', 'google', 'shares',
#         'picture', 'his', 'her', 'careful', 'firmly', 'thing', 'hard',
#         'within', 'upon', 'll', 'side', 'already', 'begin', 'here', 'good',
#         'note', 'bad', 'moment', 'both', 'starts', 'interesting', 'says',
#         'worries', 'instead', 'focused', 'international', 'island',
#         'ready', 'anyone', 'saying', 'best', 'receive', 'just', 'say',
#         'hand', 'any', 'until', 'wants', 'name', 'probably', 'law', 'mean',
#         'final', 'now', 'off', 'then', 'can', 'things', 'close', 'easy',
#         'do', 'get', 'make', 'better', 'there', 'think', 'too', 'doesn',
#         'day', 'little', 'over', 'bring', 'while', 'made', 'answer', 'you',
#         'very', 'without', 'might', 'how', 'also', 'should', 'not', 'will',
#         'second', 'out', 'if', 'right', 'an', 'away', 'take', 'but',
#         'five', 'after', 'all', 'bit', 'top', 'before', 'rose',
#         'continues', 'so', 'though', 'about', 'when', 'be', 'one', 'no',
#         'back', 'time', 'even', 'he', 'she', 'first', 'open', 'because',
#         'has', 'either', 'pretty', 'is', 'for', 're', 'what', 'least',
#         'or', 've', 'that', 'fact', 'with', 'in', 'at', 'we', 'my', 'from',
#         'been', 'it', 'enough', 'this', 'on', 'who'], dtype='<U18'),
#  array(['sacramento', 'cousin', 'helicopter', 'crawley', 'ferrell',
#         'camila', 'clare', 'nikki', 'galavis', 'pablo', 'heartbroken',
#         'couples', 'rude', 'ouch', 'agreeing', 'sexual', 'whisper', 'glad',
#         'lights', 'ladies', 'listener', 'awkward', 'hollywoodlifers',
#         'videoid', 'hl_ndn', 'propose', 'gonna', 'goodbye', 'parents',
#         'loves', 'saved', 'lovers', 'ring', 'answered', 'attitude',
#         'crowd', 'ear', 'begging', 'finale', 'dance', 'wedding',
#         'bachelor', 'picks', 'sat', 'beautiful', 'emily', 'except',
#         'father', 'tune', 'landed', 'mom', 'excited', 'josh', 'cameras',
#         'kiss', 'hug', 'seriously', 'juan', 'totally', 'wait', 'doubts',
#         'fill', 'hear', 'forever', 'children', 'naturally', 'cry', 'eager',
#         'explaining', 'kids', 'okay', 'apparently', 'physical', 'eyes',
#         'brother', 'broke', 'honest', 'dates', 'daughter', 'turns',
#         'family', 'sweet', 'met', 'brought', 'whatever', 'super', 'head',
#         'telling', 'recap', 'proved', 'true', 'life', 'conversation',
#         'course', 'felt', 'thinking', 'season', 'always', 'repeat',
#         'absolutely', 'fighting', 'man', 'loved', 'imagine', 'knew', 'let',
#         'dreams', 'me', 'kind', 'himself', 'played', 'went', 'ever',
#         'love', 'thought', 'coverage', 'looked', 'getting', 'intense',
#         'missed', 'choose', 'etc', 'lot', 'explained', 'believed', 'match',
#         'sure', 'sent', 'card', 'almost', 'leading', 'great', 'picture',
#         'really', 'him', 'his', 'her', 'king', '100', 'thing', 'date',
#         'll', 'means', 'normal', 'found', 'adding', 'home', 'having', 'jp',
#         'hands', 'looking', 'earlier', 'good', 'everything', 'moment',
#         'both', 'clear', 'together', 'along', 'instead', 'meet', 'ready',
#         'did', 'saying', 'put', 'happy', 'spent', 'fight', 'took',
#         'however', 'pick', 'finally', 'just', 'say', 'decision', 'heart',
#         'takes', 'probably', 'final', 'deal', 'purpose', 'something',
#         'alone', 'now', 'exactly', 'where', 'use', 'can', 'like', 'things',
#         'tell', 'going', 'get', 'don', 'better', 'there', 'think', 'many',
#         'too', 'see', 'doesn', 'up', 'hook', 'want', 'didn', 'much',
#         'completely', 'them', 'got', 'idea', 'wanted', 'needed', 'wasn',
#         'come', 'their', 'ride', 'are', 'next', 'left', 'down', 'meeting',
#         'made', 'answer', 'know', 'never', 'you', 'very', 'go', 'how',
#         'also', 'still', 'could', 'not', 'will', 'out', 'if', 'right',
#         'told', 'an', 'away', 'future', 'take', 'gave', 'but', 'which',
#         'after', 'all', 'couldn', 'before', 'rose', 'well', 'called', 'so',
#         'follow', 'they', 'though', 'were', 'about', 'when', 'be', 'two',
#         'no', 'was', 'than', 'more', 'us', 'time', 'as', 'even', 'he',
#         'last', 'she', 'by', 'led', 'first', 'march', '18', 'open',
#         'because', 'has', 'pretty', 'is', 'for', '10', 'what', 'or',
#         'some', 've', 'that', 'fact', 'with', 'in', 'at', 'we', 'had',
#         'my', 'been', 'have', 'would', 'it', 'said', 'this', 'on', 'who'],
#        dtype='<U18'),
#  array(['camilla', 'rocky', 'stepmom', 'sharleen', 'saint', 'lowe',
#         'dorfman', 'andi', 'taped', 'diamond', 'reassurance', 'lucia',
#         'crawley', 'runner', 'ferrell', 'bachelorette', 'clare', 'nikki',
#         'pablo', 'couples', 'ouch', 'bride', 'laughing', 'trusting',
#         'feelings', 'girls', 'sexual', 'glad', 'applause', 'awkward',
#         'propose', 'gonna', 'knee', 'goodbye', 'camera', 'ring',
#         'appearance', 'hiding', 'chris', 'studio', 'sorry', 'anger',
#         'finale', 'collective', 'appreciate', 'bachelor', 'lucky', 'weren',
#         'harrison', 'rings', 'sean', 'father', 'insulting',
#         'uncomfortable', 'engagement', 'women', 'breath', 'departure',
#         'respect', 'seriously', 'juan', 'journey', 'loud', 'host',
#         'standing', 'woman', 'awful', 'children', 'commercial', 'asking',
#         'assistant', 'fan', 'lose', 'pocket', 'ran', 'tears', 'bizarre',
#         'controversial', 'explain', 'relationship', 'accept', 'daughter',
#         'attorney', 'catherine', 'couple', 'life', 'express', 'mood',
#         'guys', 'felt', 'relief', 'sigh', 'spotlight', 'obviously',
#         'season', '32', 'appear', 'repeat', 'live', 'feeling',
#         'absolutely', 'fighting', 'fans', 'imagine', 'knew', 'let', 'me',
#         'himself', 'audience', 'night', 'barely', 'love', 'favorite',
#         'reality', 'feel', '26', 'lot', 'believed', 'sure', 'information',
#         'your', 'worst', 'words', 'really', 'his', 'quite', 'stuck', 'her',
#         'cited', '100', 'special', 'thing', 'comment', 'date', 'll',
#         'offered', 'being', 'private', 'opportunity', 'having', 'entire',
#         'comments', 'tried', 'spending', 'here', 'good', 'perfect',
#         'clearly', 'moment', 'public', 'together', 'along', 'instead',
#         'repeatedly', 'expecting', 'did', 'pair', 'happy', 'best', 'shine',
#         'taking', 'our', 'pick', 'finally', 'just', 'filled', 'soon',
#         'used', 'say', 'hand', 'under', 'signed', 'every', 'break',
#         'final', 'deal', 'something', 'bite', 'off', 'plans', 'then',
#         'use', 'done', 'can', 'like', 'tell', 'going', 'around', 'get',
#         'don', 'think', 'understand', 'see', 'doesn', 'up', 'want', 'didn',
#         'them', 'able', 'got', 'during', 'wanted', 'needed', 'their',
#         'those', 'over', 'are', 'down', 'announce', 'while', 'polled',
#         'made', 'answer', 'question', 'know', 'never', 'you', 'very', 'go',
#         'without', 'how', 'not', 'end', 'will', 'cut', 'real', 'right',
#         'told', 'an', 'away', 'future', 'may', 'gave', 'same', 'but',
#         'percent', 'after', 'part', 'most', 'three', 'all', 'bit',
#         'district', 'former', 'people', 'before', 'rose', 'keep', 'show',
#         'so', 'months', 'other', 'follow', 'they', 'about', 'asked',
#         'when', 'be', 'two', 'one', 'was', 'back', 'more', 'us', 'time',
#         'as', 'even', 'he', 'new', 'last', 'she', 'by', 'first', '19',
#         'because', 'has', 'is', 'for', 're', 'what', 'some', 've', 'that',
#         'fed', 'with', 'in', 'at', 'we', 'had', 'my', 'from', 'been',
#         'have', 'would', 'it', 'said', 'this', 'on', 'who', 'atlanta'],
#        dtype='<U18'),
#  ...]
